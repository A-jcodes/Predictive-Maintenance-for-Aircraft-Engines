# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Imported necessary libraries
import pandas as pd


# Loaded the dataset
engine_df=pd.read_csv(r"C:\Users\user\Downloads\Data Science\aircraft_engine_maintenance.csv")

# Displayed the first few rows of the dataset
engine_df.head()
# Out:
#    Unnamed: 0  Engine_ID            Timestamp  Temperature    Pressure  \
# 0           0          1  2021-01-01 00:00:00   491.953274         NaN
# 1           1          1  2021-01-01 12:30:00   567.414022  129.808855
# 2           2          1  2021-01-02 01:00:00   552.161384  124.822135
# 3           3          1  2021-01-02 13:30:00          NaN  117.691465
# 4           4          1  2021-01-03 02:00:00          NaN  129.560121
#
#    Rotational_Speed  Engine_Health  Engine_Failure
# 0       2801.303972            NaN               0
# 1       2835.028192       1.619966               0
# 2       3257.107364       1.665153               0
# 3       3038.128929            NaN               0
# 4       3018.402598            NaN               0

# %%
engine_df.columns
# Out:
# Index(['Unnamed: 0', 'Engine_ID', 'Timestamp', 'Temperature', 'Pressure',
#        'Rotational_Speed', 'Engine_Health', 'Engine_Failure'],
#       dtype='object')

# %%
len(engine_df)
# Out:
# 10505

# %%
engine_df['Engine_ID'].value_counts()
# Out:
# Engine_ID
# 1    2101
# 2    2101
# 3    2101
# 4    2101
# 5    2101
# Name: count, dtype: int64

# %%
engine_df['Engine_Failure'].value_counts()
# Out:
# Engine_Failure
# 0    9794
# 1     711
# Name: count, dtype: int64

# %% [markdown]
# #### Data Cleaning
# 1. Handling Missing Values:

# %%
engine_df.isnull()
# Out:
#        Unnamed: 0  Engine_ID  Timestamp  Temperature  Pressure  \
# 0           False      False      False        False      True
# 1           False      False      False        False     False
# 2           False      False      False        False     False
# 3           False      False      False         True     False
# 4           False      False      False         True     False
# ...           ...        ...        ...          ...       ...
# 10500       False      False      False        False     False
# 10501       False      False      False        False     False
# 10502       False      False      False         True     False
# 10503       False      False      False        False     False
# 10504       False      False      False        False     False
#
#        Rotational_Speed  Engine_Health  Engine_Failure
# 0                 False           True           False
# 1                 False          False           False
# 2                 False          False           False
# 3                 False           True           False
# 4                 False           True           False
# ...                 ...            ...             ...
# 10500             False          False           False
# 10501             False          False           False
# 10502             False           True           False
# 10503             False          False           False
# 10504             False          False           False
#
# [10505 rows x 8 columns]

# %%
# Check for missing values
engine_df.isnull().sum()
# Out:
# Unnamed: 0             0
# Engine_ID              0
# Timestamp              0
# Temperature          490
# Pressure             537
# Rotational_Speed     522
# Engine_Health       1010
# Engine_Failure         0
# dtype: int64

# %%
# Displayed columns with missing values
engine_df['Temperature']
# Out:
# 0        491.953274
# 1        567.414022
# 2        552.161384
# 3               NaN
# 4               NaN
#             ...
# 10500    476.847716
# 10501    440.494330
# 10502           NaN
# 10503    581.269776
# 10504    503.320885
# Name: Temperature, Length: 10505, dtype: float64

# %%
missing_values=engine_df.isnull().sum()
missing_values[missing_values>0].index
# Out:
# Index(['Temperature', 'Pressure', 'Rotational_Speed', 'Engine_Health'], dtype='object')

# %%
missing_values=engine_df.isnull().sum()
missing_values[missing_values>0].index
missing_columns=missing_values[missing_values>0].index
missing_columns
# Out:
# Index(['Temperature', 'Pressure', 'Rotational_Speed', 'Engine_Health'], dtype='object')

# %%
# Introduce missing values(replace the missing values with some methods of central tendency: mean/median)

engine_df.fillna(engine_df[missing_columns].mean(), inplace=True)

# Set a seed for reproducibility


# Randomly select indices to introduce missing values


# Introduce missing values in the selected indices for "Temperature" and "Pressure"


# Display the dataset with missing values

# %%
engine_df
# Out:
#        Unnamed: 0  Engine_ID            Timestamp  Temperature    Pressure  \
# 0               0          1  2021-01-01 00:00:00   491.953274  119.945267
# 1               1          1  2021-01-01 12:30:00   567.414022  129.808855
# 2               2          1  2021-01-02 01:00:00   552.161384  124.822135
# 3               3          1  2021-01-02 13:30:00   499.829973  117.691465
# 4               4          1  2021-01-03 02:00:00   499.829973  129.560121
# ...           ...        ...                  ...          ...         ...
# 10500       10500          5  2023-12-28 16:00:00   476.847716  132.820792
# 10501       10501          5  2023-12-29 04:30:00   440.494330  105.342947
# 10502       10502          5  2023-12-29 17:00:00   499.829973  117.517511
# 10503       10503          5  2023-12-30 05:30:00   581.269776  142.853142
# 10504       10504          5  2023-12-30 18:00:00   503.320885  132.321638
#
#        Rotational_Speed  Engine_Health  Engine_Failure
# 0           2801.303972       1.397576               0
# 1           2835.028192       1.619966               0
# 2           3257.107364       1.665153               0
# 3           3038.128929       1.397576               0
# 4           3018.402598       1.397576               0
# ...                 ...            ...             ...
# 10500       2893.279870       1.105070               0
# 10501       2971.973324       1.400521               0
# 10502       2917.398994       1.397576               0
# 10503       3230.471424       1.735149               0
# 10504       3108.031673       1.497677               0
#
# [10505 rows x 8 columns]

# %%
# Check for missing values
engine_df.isnull().sum()
# Out:
# Unnamed: 0          0
# Engine_ID           0
# Timestamp           0
# Temperature         0
# Pressure            0
# Rotational_Speed    0
# Engine_Health       0
# Engine_Failure      0
# dtype: int64

# %%
# Display columns with missing values
missing_values=engine_df.isnull().sum()
missing_values[missing_values>0].index
# Out:
# Index([], dtype='object')

# %% [markdown]
# 2. Handling Outliers:

# %%
# Calculate IQR for each column
columns_to_check=engine_df[['Temperature', 'Pressure', 'Rotational_Speed', 'Engine_Health']]
Q3=columns_to_check.quantile(0.75)
Q3
# Out:
# Temperature          530.639835
# Pressure             128.941962
# Rotational_Speed    3127.412135
# Engine_Health          1.545940
# Name: 0.75, dtype: float64

# %%
columns_to_check=engine_df[['Temperature', 'Pressure', 'Rotational_Speed', 'Engine_Health']]
Q1=columns_to_check.quantile(0.25)
Q1
# Out:
# Temperature          468.989918
# Pressure             111.129590
# Rotational_Speed    2874.087481
# Engine_Health          1.250840
# Name: 0.25, dtype: float64

# %%
# Identify outliers using IQR
IQR=Q3-Q1
IQR
# Out:
# Temperature          61.649917
# Pressure             17.812372
# Rotational_Speed    253.324654
# Engine_Health         0.295101
# dtype: float64

# %%
outliers=((columns_to_check<(Q1-1.5*IQR)) | (columns_to_check>(Q3+1.5*IQR))).any(axis=1)
outliers
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10500    False
# 10501    False
# 10502    False
# 10503    False
# 10504    False
# Length: 10505, dtype: bool

# %%
# Display the number of outliers
engine_df[outliers]
# Out:
#        Unnamed: 0  Engine_ID            Timestamp  Temperature    Pressure  \
# 44             44          1  2021-01-23 22:00:00   370.913041   78.304387
# 123           123          1  2021-03-06 01:30:00   355.981428  100.295958
# 174           174          1  2021-04-01 15:00:00   553.515771  142.493526
# 177           177          1  2021-04-03 04:30:00   578.490599  132.107362
# 309           309          1  2021-06-10 22:30:00   372.108814  108.447542
# ...           ...        ...                  ...          ...         ...
# 10310       10310          5  2023-09-20 17:00:00   495.131125  108.620766
# 10367       10367          5  2023-10-20 09:30:00   414.342339   83.087994
# 10388       10388          5  2023-10-31 08:00:00   481.866975  106.143293
# 10423       10423          5  2023-11-18 13:30:00   385.460414   78.518629
# 10461       10461          5  2023-12-08 08:30:00   435.282033  107.476826
#
#        Rotational_Speed  Engine_Health  Engine_Failure
# 44          2931.295646       1.217130               0
# 123         2706.891168       1.302672               0
# 174         3636.686784       1.800130               0
# 177         2789.782811       1.990961               0
# 309         3152.587542       1.249401               0
# ...                 ...            ...             ...
# 10310       2481.344907       1.196934               0
# 10367       3275.703160       0.948484               0
# 10388       3528.295060       0.894677               0
# 10423       3289.352741       0.976141               0
# 10461       2673.964158       0.756151               0
#
# [464 rows x 8 columns]

# %%
outliers=((columns_to_check<(Q1-1.5*IQR)) | (columns_to_check>(Q3+1.5*IQR))).sum()
outliers
# Out:
# Temperature         131
# Pressure            137
# Rotational_Speed    115
# Engine_Health       144
# dtype: int64

# %%
# Remove outliers based on IQR: to do this, negate the command for the already established outliers
engine_df= engine_df[~outliers]
engine_df
# Out:
#        Unnamed: 0  Engine_ID            Timestamp  Temperature    Pressure  \
# 0               0          1  2021-01-01 00:00:00   491.953274  119.945267
# 1               1          1  2021-01-01 12:30:00   567.414022  129.808855
# 2               2          1  2021-01-02 01:00:00   552.161384  124.822135
# 3               3          1  2021-01-02 13:30:00   499.829973  117.691465
# 4               4          1  2021-01-03 02:00:00   499.829973  129.560121
# ...           ...        ...                  ...          ...         ...
# 10500       10500          5  2023-12-28 16:00:00   476.847716  132.820792
# 10501       10501          5  2023-12-29 04:30:00   440.494330  105.342947
# 10502       10502          5  2023-12-29 17:00:00   499.829973  117.517511
# 10503       10503          5  2023-12-30 05:30:00   581.269776  142.853142
# 10504       10504          5  2023-12-30 18:00:00   503.320885  132.321638
#
#        Rotational_Speed  Engine_Health  Engine_Failure
# 0           2801.303972       1.397576               0
# 1           2835.028192       1.619966               0
# 2           3257.107364       1.665153               0
# 3           3038.128929       1.397576               0
# 4           3018.402598       1.397576               0
# ...                 ...            ...             ...
# 10500       2893.279870       1.105070               0
# 10501       2971.973324       1.400521               0
# 10502       2917.398994       1.397576               0
# 10503       3230.471424       1.735149               0
# 10504       3108.031673       1.497677               0
#
# [10041 rows x 8 columns]

# %%
# Display the dataset after handling outliers
engine_df
# Out:
#        Unnamed: 0  Engine_ID            Timestamp  Temperature    Pressure  \
# 0               0          1  2021-01-01 00:00:00   491.953274  119.945267
# 1               1          1  2021-01-01 12:30:00   567.414022  129.808855
# 2               2          1  2021-01-02 01:00:00   552.161384  124.822135
# 3               3          1  2021-01-02 13:30:00   499.829973  117.691465
# 4               4          1  2021-01-03 02:00:00   499.829973  129.560121
# ...           ...        ...                  ...          ...         ...
# 10500       10500          5  2023-12-28 16:00:00   476.847716  132.820792
# 10501       10501          5  2023-12-29 04:30:00   440.494330  105.342947
# 10502       10502          5  2023-12-29 17:00:00   499.829973  117.517511
# 10503       10503          5  2023-12-30 05:30:00   581.269776  142.853142
# 10504       10504          5  2023-12-30 18:00:00   503.320885  132.321638
#
#        Rotational_Speed  Engine_Health  Engine_Failure
# 0           2801.303972       1.397576               0
# 1           2835.028192       1.619966               0
# 2           3257.107364       1.665153               0
# 3           3038.128929       1.397576               0
# 4           3018.402598       1.397576               0
# ...                 ...            ...             ...
# 10500       2893.279870       1.105070               0
# 10501       2971.973324       1.400521               0
# 10502       2917.398994       1.397576               0
# 10503       3230.471424       1.735149               0
# 10504       3108.031673       1.497677               0
#
# [10041 rows x 8 columns]

# %% [markdown]
# 3. Ensuring Data Consistency:

# %%
# Check data consistency and integrity (e.g., ensure timestamps are in order)
engine_df.sort_values(by='Timestamp', inplace=True)

# %%
engine_df.head(30)
# Out:
#       Unnamed: 0  Engine_ID            Timestamp  Temperature    Pressure  \
# 0              0          1  2021-01-01 00:00:00   491.953274  119.945267
# 6303        6303          4  2021-01-01 00:00:00   505.570432  125.381735
# 4202        4202          3  2021-01-01 00:00:00   454.812683  115.522981
# 2101        2101          2  2021-01-01 00:00:00   515.077480  119.945267
# 8404        8404          5  2021-01-01 00:00:00   541.184456  119.543472
# 6304        6304          4  2021-01-01 12:30:00   522.398252  120.273729
# 2102        2102          2  2021-01-01 12:30:00   518.098019  134.673669
# 1              1          1  2021-01-01 12:30:00   567.414022  129.808855
# 8405        8405          5  2021-01-01 12:30:00   501.726213  125.358999
# 4203        4203          3  2021-01-01 12:30:00   561.112862  131.390238
# 8406        8406          5  2021-01-02 01:00:00   497.489777  127.450507
# 2103        2103          2  2021-01-02 01:00:00   467.015555  115.253163
# 4204        4204          3  2021-01-02 01:00:00   416.360983   97.042977
# 6305        6305          4  2021-01-02 01:00:00   522.590429  109.573479
# 2              2          1  2021-01-02 01:00:00   552.161384  124.822135
# 8407        8407          5  2021-01-02 13:30:00   499.829973  114.503377
# 2104        2104          2  2021-01-02 13:30:00   421.475869  112.615539
# 4205        4205          3  2021-01-02 13:30:00   502.437609  113.061345
# 3              3          1  2021-01-02 13:30:00   499.829973  117.691465
# 6306        6306          4  2021-01-02 13:30:00   482.652387  119.297359
# 8408        8408          5  2021-01-03 02:00:00   499.829973  105.457110
# 4              4          1  2021-01-03 02:00:00   499.829973  129.560121
# 2105        2105          2  2021-01-03 02:00:00   619.500996  140.213683
# 6307        6307          4  2021-01-03 02:00:00   517.941777  124.044498
# 4206        4206          3  2021-01-03 02:00:00   548.653088  134.147599
# 2106        2106          2  2021-01-03 14:30:00   477.040312  104.657969
# 6308        6308          4  2021-01-03 14:30:00   508.652566  129.460837
# 5              5          1  2021-01-03 14:30:00   478.963857  129.634001
# 4207        4207          3  2021-01-03 14:30:00   527.195341  137.044178
# 8409        8409          5  2021-01-03 14:30:00   521.658741  131.168798
#
#       Rotational_Speed  Engine_Health  Engine_Failure
# 0          2801.303972       1.397576               0
# 6303       3076.101970       1.397839               1
# 4202       2823.933642       1.219232               0
# 2101       2790.832119       1.397576               0
# 8404       3300.346426       1.582894               0
# 6304       2832.181271       1.896961               0
# 2102       2667.724790       1.593889               0
# 1          2835.028192       1.619966               0
# 8405       2731.333839       1.272189               0
# 4203       3050.255089       1.514231               0
# 8406       2744.815880       1.277667               0
# 2103       2744.099763       1.309536               0
# 4204       3286.511991       1.240163               0
# 6305       2968.493984       1.145236               0
# 2          3257.107364       1.665153               0
# 8407       2975.173988       1.397576               0
# 2104       3047.731659       1.163937               0
# 4205       2814.444299       1.333890               0
# 3          3038.128929       1.397576               0
# 6306       3061.504125       1.019383               0
# 8408       3098.923440       1.397576               0
# 4          3018.402598       1.397576               0
# 2105       2933.320706       1.794041               0
# 6307       3185.340836       1.680023               0
# 4206       2948.761446       1.588113               0
# 2106       3267.996965       1.593855               0
# 6308       3164.099787       1.335705               0
# 5          2980.879754       1.637636               0
# 4207       3290.584046       2.046740               0
# 8409       2891.049009       1.474829               0

# %%
# Display the cleaned dataset

engine_df.head()
# Out:
#       Unnamed: 0  Engine_ID            Timestamp  Temperature    Pressure  \
# 0              0          1  2021-01-01 00:00:00   491.953274  119.945267
# 6303        6303          4  2021-01-01 00:00:00   505.570432  125.381735
# 4202        4202          3  2021-01-01 00:00:00   454.812683  115.522981
# 2101        2101          2  2021-01-01 00:00:00   515.077480  119.945267
# 8404        8404          5  2021-01-01 00:00:00   541.184456  119.543472
#
#       Rotational_Speed  Engine_Health  Engine_Failure
# 0          2801.303972       1.397576               0
# 6303       3076.101970       1.397839               1
# 4202       2823.933642       1.219232               0
# 2101       2790.832119       1.397576               0
# 8404       3300.346426       1.582894               0

# %% [markdown]
# #### Data Exploration

# %% [markdown]
# 1. Univariate Analysis:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Univariate analysis - Histograms

# Distribution of Engine Health
fig=plt.figure(figsize=(6,4))
sns.histplot(engine_df['Engine_Health'], bins=20)
plt.xlabel('Engine_Health')
plt.ylabel('Frequency')
plt.show()

# %%
fig=plt.figure(figsize=(15,5))
plt.subplot(1,2,1)

sns.histplot(engine_df['Engine_Health'], bins=20)
plt.xlabel('Engine_Health')
plt.ylabel('Frequency')

#fig=plt.figure(figsize=(6,4))
plt.subplot(1,2,2)
sns.histplot(engine_df['Pressure'], bins=20)
plt.xlabel('Pressure')
plt.ylabel('Frequency')

plt.tight_layout()

plt.show()

# %%
fig=plt.figure(figsize=(10,7))
for i, column in enumerate(columns_to_check, 1):
    plt.subplot(2,2,i)
    sns.histplot(engine_df[column],bins=20) 
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    plt.tight_layout()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14876\2001044505.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_14876\2001044505.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_14876\2001044505.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ### Narration
# The features analysed were: Temperature,Pressure,Rotational_Speed,Engine_Health and Engine_Failure which were marked on the X-axis. The Univariate analysis revealed a reoccuring Peak period at the mid range of the day. Further analysi will be carried out to determine the conclsion for this constant rise in frequency.

# %% [markdown]
# 2. Bivariate Analysis:

# %%
# Bivariate analysis - Pairplot: selected use features
engine_df.head()
new_columns_to_check=['Temperature','Pressure','Rotational_Speed','Engine_Health','Engine_Failure']
# Out:
#       Unnamed: 0  Engine_ID            Timestamp  Temperature    Pressure  \
# 0              0          1  2021-01-01 00:00:00   491.953274  119.945267
# 4202        4202          3  2021-01-01 00:00:00   454.812683  115.522981
# 8404        8404          5  2021-01-01 00:00:00   541.184456  119.543472
# 2101        2101          2  2021-01-01 00:00:00   515.077480  119.945267
# 6303        6303          4  2021-01-01 00:00:00   505.570432  125.381735
#
#       Rotational_Speed  Engine_Health  Engine_Failure
# 0          2801.303972       1.397576               0
# 4202       2823.933642       1.219232               0
# 8404       3300.346426       1.582894               0
# 2101       2790.832119       1.397576               0
# 6303       3076.101970       1.397839               1

# %%
new_columns_to_check=['Temperature','Pressure','Rotational_Speed','Engine_Health','Engine_Failure']
sns.pairplot(engine_df[new_columns_to_check], hue='Engine_Failure');
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Observation
#
# **Temperature and Pressure**: There is a linear progression with a an even spread along with an observation of possible engine failure
#
# **Engine health and pressure**: Possiblity of engine failure increases as the the pressure increases
#
# **Engine health and Temperature**:Possiblity of engine failure increases as the the temperature increases
#
# **Rotational Speed**: Shows a spread with an increased possiblity for engine failure if the temperature and/or presure increases. Difficult to identify a pattern

# %% [markdown]
# 3. Multivariate analysis

# %%
#correlation_table
correlation_table= columns_to_check.corr()
correlation_table
# Out:
#                   Temperature  Pressure  Rotational_Speed  Engine_Health
# Temperature          1.000000  0.673471          0.013538       0.385890
# Pressure             0.673471  1.000000          0.003988       0.417722
# Rotational_Speed     0.013538  0.003988          1.000000       0.001680
# Engine_Health        0.385890  0.417722          0.001680       1.000000

# %%
# Multivariate analysis - Correlation Heatmap
correlation_table= columns_to_check.corr()
sns.heatmap(correlation_table,annot=True);

# %% [markdown]
# ### Observation
#
# **Temperature and Pressure**: This show the highest correlation of about 67%. This confirms that there is a high possibility that the engine health is affected by the temperature an pressure.
# Temperature and pressure affect all other features of the dataset to a considerable amount except from the rotional speed.
# this implies that the rotional speed does not directly affect engine failure.

# %% [markdown]
# ### Data visualization and Feature engineering
# #### Time Series of Engine Health and Engine Failure

# %%
# Data visualization - Time Series of Engine Health and Engine Failure

plt.figure(figsize=(15,10))
sns.lineplot(x='Timestamp',y='Engine_Health',data=engine_df[:300], hue='Engine_ID')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### Feature engineering

# %%
# Feature engineering - First, let's convert the timestamp column to a datetime data type.

engine_df['Timestamp']=pd.to_datetime(engine_df['Timestamp'])
engine_df['Timestamp']
# Out:
# 0       2021-01-01 00:00:00
# 6303    2021-01-01 00:00:00
# 4202    2021-01-01 00:00:00
# 2101    2021-01-01 00:00:00
# 8404    2021-01-01 00:00:00
#                 ...
# 6302    2023-12-30 18:00:00
# 4201    2023-12-30 18:00:00
# 2100    2023-12-30 18:00:00
# 8403    2023-12-30 18:00:00
# 10504   2023-12-30 18:00:00
# Name: Timestamp, Length: 10505, dtype: datetime64[ns]

# %%
# Time-related Features
engine_df['Month_of_year']=engine_df['Timestamp'].dt.month_name()
engine_df['Day_of_Week']=engine_df['Timestamp'].dt.day_name()
engine_df['Year']=engine_df['Timestamp'].dt.year
engine_df['Hour_of_day']=engine_df['Timestamp'].dt.hour

# %%
engine_df
# Out:
#        Unnamed: 0  Engine_ID           Timestamp  Temperature    Pressure  \
# 0               0          1 2021-01-01 00:00:00   491.953274  119.945267
# 4202         4202          3 2021-01-01 00:00:00   454.812683  115.522981
# 8404         8404          5 2021-01-01 00:00:00   541.184456  119.543472
# 2101         2101          2 2021-01-01 00:00:00   515.077480  119.945267
# 6303         6303          4 2021-01-01 00:00:00   505.570432  125.381735
# ...           ...        ...                 ...          ...         ...
# 4201         4201          2 2023-12-30 18:00:00   497.909259  136.980731
# 2100         2100          1 2023-12-30 18:00:00   478.704044  124.621562
# 6302         6302          3 2023-12-30 18:00:00   468.202904  103.294138
# 8403         8403          4 2023-12-30 18:00:00   484.842883  121.757481
# 10504       10504          5 2023-12-30 18:00:00   503.320885  132.321638
#
#        Rotational_Speed  Engine_Health  Engine_Failure month_of_year  \
# 0           2801.303972       1.397576               0       January
# 4202        2823.933642       1.219232               0       January
# 8404        3300.346426       1.582894               0       January
# 2101        2790.832119       1.397576               0       January
# 6303        3076.101970       1.397839               1       January
# ...                 ...            ...             ...           ...
# 4201        3001.051616       1.506987               1      December
# 2100        2825.630518       1.557776               0      December
# 6302        2759.012726       1.123990               1      December
# 8403        3214.435415       1.776111               0      December
# 10504       3108.031673       1.497677               0      December
#
#       Month_of_year Day_of_Week  Year  Hour_of_day
# 0           January      Friday  2021            0
# 4202        January      Friday  2021            0
# 8404        January      Friday  2021            0
# 2101        January      Friday  2021            0
# 6303        January      Friday  2021            0
# ...             ...         ...   ...          ...
# 4201       December    Saturday  2023           18
# 2100       December    Saturday  2023           18
# 6302       December    Saturday  2023           18
# 8403       December    Saturday  2023           18
# 10504      December    Saturday  2023           18
#
# [10041 rows x 13 columns]

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='Day_of_Week',y='Engine_Failure',data=engine_df, hue='Engine_ID')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='Year',y='Engine_Failure',data=engine_df, hue='Engine_ID')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='Hour_of_day',y='Engine_Health',data=engine_df, hue='Engine_ID')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualize time series of Engine Health and Engine Failure

plt.figure(figsize=(15,10))
sns.lineplot(x='Month_of_year',y='Engine_Health',data=engine_df, hue='Engine_ID')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
#
# Engine health is at it's peak performance at the begining of the year and then falls drastically during the summer season.
# There is an observable increase in the Engine health performance towrds the nd of the year and this remains steady till the summer season

# %%
# Temperature Category
engine_df['Temperature_Category']= pd.cut(engine_df['Temperature'],bins=[0,450,550, float('inf')], labels=['low','medium','high'])
engine_df['Temperature_Category']
# Out:
# 0        medium
# 6303     medium
# 4202     medium
# 2101     medium
# 8404     medium
#           ...
# 6302     medium
# 4201     medium
# 2100     medium
# 8403     medium
# 10504    medium
# Name: Temperature_Category, Length: 10505, dtype: category
# Categories (3, object): ['low' < 'medium' < 'high']

# %%
engine_df
# Out:
#        Unnamed: 0  Engine_ID           Timestamp  Temperature    Pressure  \
# 0               0          1 2021-01-01 00:00:00   491.953274  119.945267
# 4202         4202          3 2021-01-01 00:00:00   454.812683  115.522981
# 8404         8404          5 2021-01-01 00:00:00   541.184456  119.543472
# 2101         2101          2 2021-01-01 00:00:00   515.077480  119.945267
# 6303         6303          4 2021-01-01 00:00:00   505.570432  125.381735
# ...           ...        ...                 ...          ...         ...
# 4201         4201          2 2023-12-30 18:00:00   497.909259  136.980731
# 2100         2100          1 2023-12-30 18:00:00   478.704044  124.621562
# 6302         6302          3 2023-12-30 18:00:00   468.202904  103.294138
# 8403         8403          4 2023-12-30 18:00:00   484.842883  121.757481
# 10504       10504          5 2023-12-30 18:00:00   503.320885  132.321638
#
#        Rotational_Speed  Engine_Health  Engine_Failure month_of_year  \
# 0           2801.303972       1.397576               0       January
# 4202        2823.933642       1.219232               0       January
# 8404        3300.346426       1.582894               0       January
# 2101        2790.832119       1.397576               0       January
# 6303        3076.101970       1.397839               1       January
# ...                 ...            ...             ...           ...
# 4201        3001.051616       1.506987               1      December
# 2100        2825.630518       1.557776               0      December
# 6302        2759.012726       1.123990               1      December
# 8403        3214.435415       1.776111               0      December
# 10504       3108.031673       1.497677               0      December
#
#       Month_of_year Day_of_Week  Year  Hour_of_day Temperature_Categorical  \
# 0           January      Friday  2021            0                  medium
# 4202        January      Friday  2021            0                  medium
# 8404        January      Friday  2021            0                  medium
# 2101        January      Friday  2021            0                  medium
# 6303        January      Friday  2021            0                  medium
# ...             ...         ...   ...          ...                     ...
# 4201       December    Saturday  2023           18                  medium
# 2100       December    Saturday  2023           18                  medium
# 6302       December    Saturday  2023           18                  medium
# 8403       December    Saturday  2023           18                  medium
# 10504      December    Saturday  2023           18                  medium
#
#       Temperature_Category
# 0                   medium
# 4202                medium
# 8404                medium
# 2101                medium
# 6303                medium
# ...                    ...
# 4201                medium
# 2100                medium
# 6302                medium
# 8403                medium
# 10504               medium
#
# [10041 rows x 15 columns]

# %%
engine_df['Temperature_Category'].value_counts()
# Out:
# Temperature_Category
# medium    7407
# low       1572
# high      1526
# Name: count, dtype: int64

# %%
engine_df['Day_time'] = pd.cut(engine_df['Hour_of_day'], bins=[-1, 6, 12, 18, 24], labels=['Morning', 'Afternoon', 'Evening', 'Night'])
# Display the dataset with the new feature
engine_df
#Day_time signifies the time of day
# Out:
#        Unnamed: 0  Engine_ID           Timestamp  Temperature    Pressure  \
# 0               0          1 2021-01-01 00:00:00   491.953274  119.945267
# 6303         6303          4 2021-01-01 00:00:00   505.570432  125.381735
# 4202         4202          3 2021-01-01 00:00:00   454.812683  115.522981
# 2101         2101          2 2021-01-01 00:00:00   515.077480  119.945267
# 8404         8404          5 2021-01-01 00:00:00   541.184456  119.543472
# ...           ...        ...                 ...          ...         ...
# 6302         6302          3 2023-12-30 18:00:00   468.202904  103.294138
# 4201         4201          2 2023-12-30 18:00:00   497.909259  136.980731
# 2100         2100          1 2023-12-30 18:00:00   478.704044  124.621562
# 8403         8403          4 2023-12-30 18:00:00   484.842883  121.757481
# 10504       10504          5 2023-12-30 18:00:00   503.320885  132.321638
#
#        Rotational_Speed  Engine_Health  Engine_Failure Month_of_year  \
# 0           2801.303972       1.397576               0       January
# 6303        3076.101970       1.397839               1       January
# 4202        2823.933642       1.219232               0       January
# 2101        2790.832119       1.397576               0       January
# 8404        3300.346426       1.582894               0       January
# ...                 ...            ...             ...           ...
# 6302        2759.012726       1.123990               1      December
# 4201        3001.051616       1.506987               1      December
# 2100        2825.630518       1.557776               0      December
# 8403        3214.435415       1.776111               0      December
# 10504       3108.031673       1.497677               0      December
#
#       Day_of_Week  Year  Hour_of_day Temperature_Category Day_time
# 0          Friday  2021            0               medium  Morning
# 6303       Friday  2021            0               medium  Morning
# 4202       Friday  2021            0               medium  Morning
# 2101       Friday  2021            0               medium  Morning
# 8404       Friday  2021            0               medium  Morning
# ...           ...   ...          ...                  ...      ...
# 6302     Saturday  2023           18               medium  Evening
# 4201     Saturday  2023           18               medium  Evening
# 2100     Saturday  2023           18               medium  Evening
# 8403     Saturday  2023           18               medium  Evening
# 10504    Saturday  2023           18               medium  Evening
#
# [10505 rows x 14 columns]

# %%
# Pressure to Temperature Ratio
engine_df['ptr']= engine_df['Temperature']/ engine_df['Pressure']
engine_df['ptr']
ptr=engine_df['ptr']
ptr
# Out:
# 0        4.101481
# 6303     4.032249
# 4202     3.936989
# 2101     4.294271
# 8404     4.527093
#            ...
# 6302     4.532715
# 4201     3.634885
# 2100     3.841262
# 8403     3.982038
# 10504    3.803769
# Name: ptr, Length: 10505, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='ptr',y='Engine_Failure',data=engine_df[:500], hue='Engine_ID')
plt.xticks(rotation=90)
plt.show()

# %%
# Feature engineering - Binning 'Hour_of_Day'


# Display the dataset with the new feature

# %%
# Grouped Bar Chart
plt.figure(figsize=(8,6))
sns.barplot(data=engine_df,y='Engine_Health',x='Day_time',hue='Temperature_Category');

# %%
# Histogram
plt.figure(figsize=(8,6))

sns.histplot(x='Engine_Health', data=engine_df, hue='Day_time')

plt.show()
